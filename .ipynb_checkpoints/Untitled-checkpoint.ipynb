# %%
import os
import matplotlib.pyplot as plt 
import numpy as np
import tensorflow as tf 
from tqdm import tqdm

# %% [markdown]
# # Anti-Spoofing

# %%
FAKE_PATHS = os.listdir("Data/fake")
REAL_PATHS = os.listdir("Data/real")
print("{} Fake examples:".format(len(FAKE_PATHS)))
print("{} Real examples:".format(len(REAL_PATHS)))
# Out:
# 150 Fake examples:
# 161 Real examples:

# %%
img = plt.imread("Data/fake/0.png")
plt.imshow(img)
plt.title("Fake Person Class")
print(img.shape)
# Out:
# (210, 146, 3)

# %%
img = plt.imread("Data/Real/0.png")
plt.imshow(img)
plt.title("Real Class")
# Out:
# Text(0.5, 1.0, 'Real Class')

# %%
# Out:
# (698, 382, 3)

# %%
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization
from tensorflow.keras import Input
from tensorflow.keras.models import Model

class spoofnet():
    def __init__(self, height, width, n_channels)
        self.height = height
        self. width = width
        self.n_channels = n_channels
        
        self.c1 = Conv2D(32, (3,3), padding = "same")
        self.c2 = Conv2D(64, (3,3), Padding = "Same")
        self.batch_n = BatchNormalization()
        self.max
        
    def build_model():
        inputs = Input((256, 256, 3))(x)
        x = BatchNormalization()(inputs)(x)
        x = (x)
        x = Conv2D(32, (3,3), Padding = "Same")(x)

        x = BatchNormalization()(x)
        x = MaxPool2D((2,2))(x)
        x = Conv2D(64, (3,3), padding = "same")(x)
        x = Conv2D(64, (3,3), Padding = "Same")(x)

        x = BatchNormalization()(x)
        (x)x = MaxPool2D((2,2))(x)
        x = Flatten()('relu')(x)

        x = Dense(128, activation = 'relu')(x)
        x = Dense(32, activation = 'relu')(x)
        outputs = Dense(1, activation = 'sigmoid')(x)
        net = Model(inputs = inputs, outputs = ouputs)
        return net
